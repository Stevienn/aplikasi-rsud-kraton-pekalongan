# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('ICD10codes.csv')

# %%
df
# Out:
#         A00    0   A000 Cholera due to Vibrio cholerae 01, biovar cholerae  \
# 0       A00    1   A001    Cholera due to Vibrio cholerae 01, biovar eltor
# 1       A00    9   A009                               Cholera, unspecified
# 2      A010    0  A0100                         Typhoid fever, unspecified
# 3      A010    1  A0101                                 Typhoid meningitis
# 4      A010    2  A0102               Typhoid fever with heart involvement
# ...     ...  ...    ...                                                ...
# 71698  Z991    2  Z9912  Encounter for respirator dependence during pow...
# 71699  Z992  NaN   Z992                       Dependence on renal dialysis
# 71700  Z993  NaN   Z993                           Dependence on wheelchair
# 71701  Z998    1  Z9981                  Dependence on supplemental oxygen
# 71702  Z998    9  Z9989  Dependence on other enabling machines and devices
#
#       Cholera due to Vibrio cholerae 01, biovar cholerae.1  \
# ...

# %%
df_icd_10 = df[['A000', 'Cholera due to Vibrio cholerae 01, biovar cholerae.1']].rename(columns={
    'A000': 'kode_icd',
    'Cholera due to Vibrio cholerae 01, biovar cholerae.1': 'deskripsi'
})

df_icd_10.to_csv('icd-10.csv', index=False)

print('Berhasil Disimpan')
# Out:
# Berhasil Disimpan

# %%
df_icd_10
# Out:
#       kode_icd                                          deskripsi
# 0         A001    Cholera due to Vibrio cholerae 01, biovar eltor
# 1         A009                               Cholera, unspecified
# 2        A0100                         Typhoid fever, unspecified
# 3        A0101                                 Typhoid meningitis
# 4        A0102               Typhoid fever with heart involvement
# ...        ...                                                ...
# 71698    Z9912  Encounter for respirator [ventilator] dependen...
# 71699     Z992                       Dependence on renal dialysis
# 71700     Z993                           Dependence on wheelchair
# 71701    Z9981                  Dependence on supplemental oxygen
# 71702    Z9989  Dependence on other enabling machines and devices
#
# [71703 rows x 2 columns]
